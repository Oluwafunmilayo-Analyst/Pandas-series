# %% [markdown]
# <a href="https://colab.research.google.com/github/Oluwafunmilayo-Analyst/Pandas-series/blob/main/pandas_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas series is like a column in a table. it it a one-dimensional array holding data of any tyoe(integer, float, python objects,string e.t.c). The axis labels are collectively called index. Pandas series is nothing but a column in an excel sheet.it doesnt allow a mixture of data types. it is identified just by rows and index

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
pop=[23.45,45.88,98.25,15.49,80.940,60.665,127.061,64.511,318.523,35.467,63.951]

# %%
type(pop)
# Out:
# list

# %%
for i in pop:
  print(i)
# Out:
# 23.45
# 45.88
# 98.25
# 15.49
# 80.94
# 60.665
# 127.061
# 64.511
# 318.523
# 35.467
# 63.951

# %%
p_pop_2=pd.Series([23.45,45.88,98.25,15.49,80.940,60.665,127.061,64.511,318.523,35.467,63.951])
p_pop_2
# Out:
# 0      23.450
# 1      45.880
# 2      98.250
# 3      15.490
# 4      80.940
# 5      60.665
# 6     127.061
# 7      64.511
# 8     318.523
# 9      35.467
# 10     63.951
# dtype: float64

# %%
p_pop=pd.Series(pop)
p_pop
# Out:
# 0      23.450
# 1      45.880
# 2      98.250
# 3      15.490
# 4      80.940
# 5      60.665
# 6     127.061
# 7      64.511
# 8     318.523
# 9      35.467
# 10     63.951
# dtype: float64

# %%
p_pop.index
# Out:
# RangeIndex(start=0, stop=11, step=1)

# %%
p_pop.values
# Out:
# array([ 23.45 ,  45.88 ,  98.25 ,  15.49 ,  80.94 ,  60.665, 127.061,
#         64.511, 318.523,  35.467,  63.951])

# %%
p_pop[0]
# Out:
# 23.45

# %%
#in millions
g7_pop=pd.Series([35.467,63.951,80.940,60.665,127.061,64.511,318.523])

# %%
type(g7_pop)
# Out:
# pandas.core.series.Series

# %%
g7_pop.head(3) #head by default gives the top 5 values
# Out:
# 0    35.467
# 1    63.951
# 2    80.940
# dtype: float64

# %%
g7_pop.tail() # tail by default gives the last 5 values
# Out:
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# dtype: float64

# %%
#someone might not know we are representing population in millions of inhabitants. Series can have a name. to better document the purpose of the series:

# %%
a = range(0,12,2)
for i in a:
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# dtype: float64

# %%
g7_pop.name='G7 Population in Millions'

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
pd.Series([23.45,45.88,98.25,15.49,80.490,60.665,127.061,64.511,318.523,35.467,63.951],name='G7 Population in Millions')
# Out:
# 0      23.450
# 1      45.880
# 2      98.250
# 3      15.490
# 4      80.490
# 5      60.665
# 6     127.061
# 7      64.511
# 8     318.523
# 9      35.467
# 10     63.951
# Name: G7 Population in Millions, dtype: float64

# %%
#we can say that series look like"ordered dictionatires'. We can actually create Series out of Dictionaries
country={'Canada': 35.467,
         'France': 63.951,
         'Germany': 80.94,
         'Italy': 60.665,
         'Japan': 127.061,
         'United Kingdom': 64.511,
         'United States': 318.523}

# %%
country
# Out:
# {'Canada': 35.467,
#  'France': 63.951,
#  'Germany': 80.94,
#  'Italy': 60.665,
#  'Japan': 127.061,
#  'United Kingdom': 64.511,
#  'United States': 318.523}

# %%
country_series=pd.Series(country, name='G7 Population in Millions')

# %%
country_series
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
country_series['Canada':'Italy']
# Out:
# Canada     35.467
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: G7 Population in Millions, dtype: float64

# %%
country_series[0:4]
# Out:
# Canada     35.467
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: G7 Population in Millions, dtype: float64

# %%
country_series[:4]
# Out:
# Canada     35.467
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: G7 Population in Millions, dtype: float64

# %%
#Even a better way
pd.Series(
    [35.467,63.951,80.94,60.665,127.061,64.511,318.523],
    index=['Canada','France','Germany', 'Italy','Japan','United Kingdom','United States'],
    name='G7 Population in Millions')
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g8=pd.Series(g7_pop) # you can also create Series out of other series, specifying indexes

# %%
g8
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g8.index=['France','Germany','Italy','Spain','Nigeria','Togo','Cameroon']

# %%
g8
# Out:
# France       35.467
# Germany      63.951
# Italy        80.940
# Spain        60.665
# Nigeria     127.061
# Togo         64.511
# Cameroon    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g8.France
# Out:
# 35.467

# %%
g8[0]
# Out:
# 35.467

# %%
#Modifying series
g7_pop
# Out:
# France       35.467
# Germany      63.951
# Italy        80.940
# Spain        60.665
# Nigeria     127.061
# Togo         64.511
# Cameroon    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop['Canada']=40.5

# %%
g7_pop<70
# Out:
# France      False
# Germany     False
# Italy       False
# Spain       False
# Nigeria     False
# Togo        False
# Cameroon    False
# Canada      False
# Name: G7 Population in Millions, dtype: bool

# %%
g7_pop[g7_pop<70]=99.99

# %%
#Operations and methods- series also support vectorized operations and aggregation functions as Numpy:
g7_70 = g7_pop>70

# %%
g7_pop[gr_70]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-42b875c51aa0> in <cell line: 1>()
# ----> 1 g7_pop[gr_70]
#
# NameError: name 'gr_70' is not defined

# %%
g7_pop.mean()
# Out:
# 128.30925000000002

# %%
g7_pop[g7_pop>g7_pop.mean()]
# Out:
# Cameroon    318.523
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.std()
# Out:
# 77.86120826325705

# %%
g7_pop>g7_pop.mean()-g7_pop.std()/2
# Out:
# France       True
# Germany      True
# Italy       False
# Spain        True
# Nigeria      True
# Togo         True
# Cameroon     True
# Canada       True
# Name: G7 Population in Millions, dtype: bool

# %%
g7_pop>g7_pop.mean()+g7_pop.std()/2
# Out:
# France      False
# Germany     False
# Italy       False
# Spain       False
# Nigeria     False
# Togo        False
# Cameroon     True
# Canada      False
# Name: G7 Population in Millions, dtype: bool

# %%
g7_pop[(g7_pop>g7_pop.mean()-g7_pop.std()/2)| (g7_pop>g7_pop.mean()+g7_pop.std()/2)]
# Out:
# France       99.990
# Germany      99.990
# Spain        99.990
# Nigeria     127.061
# Togo         99.990
# Cameroon    318.523
# Canada       99.990
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop*1000000
# Out:
# France       99990000.0
# Germany      99990000.0
# Italy        80940000.0
# Spain        99990000.0
# Nigeria     127061000.0
# Togo         99990000.0
# Cameroon    318523000.0
# Canada       99990000.0
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop.mean()
# Out:
# 128.30925000000002

# %%
np.log(g7_pop)
# Out:
# France      4.605070
# Germany     4.605070
# Italy       4.393708
# Spain       4.605070
# Nigeria     4.844667
# Togo        4.605070
# Cameroon    5.763695
# Canada      4.605070
# Name: G7 Population in Millions, dtype: float64

# %%
import numpy as np

# %%
g7_pop['France':'Italy'].mean()
# Out:
# 93.63999999999999

# %%
#Boolean arrays
g7_pop
# Out:
# France       99.990
# Germany      99.990
# Italy        80.940
# Spain        99.990
# Nigeria     127.061
# Togo         99.990
# Cameroon    318.523
# Canada       99.990
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop>80
# Out:
# France      True
# Germany     True
# Italy       True
# Spain       True
# Nigeria     True
# Togo        True
# Cameroon    True
# Canada      True
# Name: G7 Population in Millions, dtype: bool

# %%
g7_pop[g7_pop>80]
# Out:
# France       99.990
# Germany      99.990
# Italy        80.940
# Spain        99.990
# Nigeria     127.061
# Togo         99.990
# Cameroon    318.523
# Canada       99.990
# Name: G7 Population in Millions, dtype: float64

# %%
~ not
| or
& and
# Out:
#   File "<ipython-input-63-59d7df7c288a>", line 1
#     ~ not
#       ^
# SyntaxError: invalid syntax

# %%
g7_pop[(g7_pop>80)| (g7_pop<40)]
# Out:
# France       99.990
# Germany      99.990
# Italy        80.940
# Spain        99.990
# Nigeria     127.061
# Togo         99.990
# Cameroon    318.523
# Canada       99.990
# Name: G7 Population in Millions, dtype: float64

# %%
g7_pop[(g7_pop>80)&(g7_pop<200)]
# Out:
# France      99.990
# Germany     99.990
# Italy       80.940
# Spain       99.990
# Nigeria    127.061
# Togo        99.990
# Canada      99.990
# Name: G7 Population in Millions, dtype: float64

# %% [markdown]
# Pandas Dataframe- is a two dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes(row and columns). Pandas dataframe consists of three principal components: the data,rows and columns.Probably the most important data structure of pandas is the DataFrame.it is a tabular structure tightly integrated with Series.
# Creating Dataframes manually can be tedious. 99% of the time you will be pulling the data from a database,a csv file or the web. but still, you can create a dataframe by specifying the columns and values:

# %%
import pandas as pd

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United State       318.523  17348075       9525067  0.915   America

# %%
df=pd.DataFrame({
    'Population':[35.467,63.951,80.94,60.665,127.061,64.511,318.523],
    'GDP':[
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area':[
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI':[
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent':[
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}, columns=['Population','GDP','Surface Area','HDI','Continent'],
                index=[
                    'Canada',
                    'France',
                    'Germany',
                    'Italy',
                    'Japan',
                    'United Kingdom',
                    'United State',
                ]) #the columns attribut is optional. i am using it to keep the same order as in the picture above. Dataframe also have indexes. As you can see inthe 'tableabove, pandas has assigned a numeric,autoincremental index automatically to each 'rowin out dataframe. in our case, we know that each row represents a country, so we will just reassign the index;z:

# %%
df.index=['Canada','France','Germany','Italy','Japan','United Kingdom','United state']

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United State'],
#       dtype='object')

# %%
df.info() #details of your data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United State
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 636.0+ bytes

# %%
import numpy as np

# %%
df.iloc[2,1]= np.nan

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent
# Canada              35.467   1785387.0       9984670  0.913   America
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United State
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           6 non-null      float64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 636.0+ bytes

# %%
df.size
# Out:
# 35

# %%
df.shape #shape of your element  row xcol
# Out:
# (7, 5)

# %%
df.shape[0] #no of row
# Out:
# 7

# %%
df.shape[1] # number of col
# Out:
# 5

# %%
df.describe()# statistical description of data excluding obj data type and numerical is involved
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  6.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.281216e+06  3.061327e+06  0.900429
# std     97.249970  5.990146e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.334230e+06  3.292250e+05  0.889500
# 50%     64.511000  2.891863e+06  3.779300e+05  0.907000
# 75%    104.000500  4.189285e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.describe(include='all') #analysis of but object datatype and numerical datatype
# Out:
#         Population           GDP  Surface Area       HDI Continent
# count     7.000000  6.000000e+00  7.000000e+00  7.000000         7
# unique         NaN           NaN           NaN       NaN         3
# top            NaN           NaN           NaN       NaN    Europe
# freq           NaN           NaN           NaN       NaN         4
# mean    107.302571  5.281216e+06  3.061327e+06  0.900429       NaN
# std      97.249970  5.990146e+06  4.576187e+06  0.016592       NaN
# min      35.467000  1.785387e+06  2.424950e+05  0.873000       NaN
# 25%      62.308000  2.334230e+06  3.292250e+05  0.889500       NaN
# 50%      64.511000  2.891863e+06  3.779300e+05  0.907000       NaN
# 75%     104.000500  4.189285e+06  5.082873e+06  0.914000       NaN
# max     318.523000  1.734808e+07  9.984670e+06  0.916000       NaN

# %%
df.dtypes #data types
# Out:
# Population      float64
# GDP             float64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.dtypes.value_counts() # the number of data type in the
# Out:
# float64    3
# int64      1
# object     1
# dtype: int64

# %%
#indexing, selection and Slicing- individual columns in the DataFrame can be selected with regular indexing. Each column is represented as a series: Always use loc and iloc to reduce ambiguity, specially with Dataframes with numeri indexes
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent
# Canada              35.467   1785387.0       9984670  0.913   America
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America

# %%
df['Population']
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United State      318.523
# Name: Population, dtype: float64

# %%
type(df['Population'])
# Out:
# pandas.core.series.Series

# %%
#multiple columns can also be selected and retain the data type as dataframe:
df[['Population']]
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United State       318.523

# %%
type(df[['Population']])
# Out:
# pandas.core.frame.DataFrame

# %%
#in this case, the result is another data frame. slicing works differently, it acts at 'row level, and can be counter intuitive
df[1:3]
# Out:
#          Population        GDP  Surface Area    HDI Continent
# France       63.951  2833687.0        640679  0.888    Europe
# Germany      80.940        NaN        357114  0.916    Europe

# %%
#row level selection works better with loc and iloc which are recommended over regular 'direct slicing (df[:])
#loc selects rows matching the given index:
df.loc['Canada']
# Out:
# Population         35.467
# GDP             1785387.0
# Surface Area      9984670
# HDI                 0.913
# Continent         America
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population         318.523
# GDP             17348075.0
# Surface Area       9525067
# HDI                  0.915
# Continent          America
# Name: United State, dtype: object

# %%
df.loc['Italy']
# Out:
# Population         60.665
# GDP             2167744.0
# Surface Area       301336
# HDI                 0.873
# Continent          Europe
# Name: Italy, dtype: object

# %%
df.loc['France':'Italy']
# Out:
#          Population        GDP  Surface Area    HDI Continent
# France       63.951  2833687.0        640679  0.888    Europe
# Germany      80.940        NaN        357114  0.916    Europe
# Italy        60.665  2167744.0        301336  0.873    Europe

# %%
df.iloc[:3,-3:-1]
# Out:
#          Surface Area    HDI
# Canada        9984670  0.913
# France         640679  0.888
# Germany        357114  0.916

# %%
type(df.loc['France':'Italy','Population'])
# Out:
# pandas.core.series.Series

# %%
type(df.loc['France':'Italy',['Population']])
# Out:
# pandas.core.frame.DataFrame

# %%
#Dropping stuffs it doesnt affect the original dataframe
df.drop('Canada')
# Out:
#                 Population         GDP  Surface Area    HDI Continent
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America

# %%
df.drop(['Canada','Japan'])
# Out:
#                 Population         GDP  Surface Area    HDI Continent
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America

# %%
df.drop(columns=['Population','HDI'])
# Out:
#                        GDP  Surface Area Continent
# Canada           1785387.0       9984670   America
# France           2833687.0        640679    Europe
# Germany                NaN        357114    Europe
# Italy            2167744.0        301336    Europe
# Japan            4602367.0        377930      Asia
# United Kingdom   2950039.0        242495    Europe
# United State    17348075.0       9525067   America

# %%
df.drop(['Italy','Canada'],axis=0) #remove data from row
# Out:
#                 Population         GDP  Surface Area    HDI Continent
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America

# %%
df.drop(['Population','HDI'],axis=1) #removes columns
# Out:
#                        GDP  Surface Area Continent
# Canada           1785387.0       9984670   America
# France           2833687.0        640679    Europe
# Germany                NaN        357114    Europe
# Italy            2167744.0        301336    Europe
# Japan            4602367.0        377930      Asia
# United Kingdom   2950039.0        242495    Europe
# United State    17348075.0       9525067   America

# %%
df.drop(['Population','HDI'],axis='columns')
# Out:
#                        GDP  Surface Area Continent
# Canada           1785387.0       9984670   America
# France           2833687.0        640679    Europe
# Germany                NaN        357114    Europe
# Italy            2167744.0        301336    Europe
# Japan            4602367.0        377930      Asia
# United Kingdom   2950039.0        242495    Europe
# United State    17348075.0       9525067   America

# %%
df.drop(['Canada','Germany'],axis='rows')
# Out:
#                 Population         GDP  Surface Area    HDI Continent
# France              63.951   2833687.0        640679  0.888    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America

# %% [markdown]
# All these drop methods return a new dataframe. if you would like to modify it'in place', you can use the inplace attribut. it removes data permanently. expressed as inplace = True/False Examples below

# %%
#modifying dataframe
#adding a new column
df['Language']='English'

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent Language
# Canada              35.467   1785387.0       9984670  0.913   America  English
# France              63.951   2833687.0        640679  0.888    Europe  English
# Germany             80.940         NaN        357114  0.916    Europe  English
# Italy               60.665   2167744.0        301336  0.873    Europe  English
# Japan              127.061   4602367.0        377930  0.891      Asia  English
# United Kingdom      64.511   2950039.0        242495  0.907    Europe  English
# United State       318.523  17348075.0       9525067  0.915   America  English

# %%
df.loc['Japan','Language'] ='Japanese'

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387.0       9984670  0.913   America
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America
#
#                 Language
# Canada           English
# France           English
# Germany          English
# Italy            English
# Japan           Japanese
# United Kingdom   English
# United State     English

# %%
df.iloc[1,-1] = 'Italian'

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387.0       9984670  0.913   America
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America
#
#                 Language
# Canada           English
# France           Italian
# Germany          English
# Italy            English
# Japan           Japanese
# United Kingdom   English
# United State     English

# %%
#Rename columns
df.rename(
    columns={
        'HDI':'Human Development Index',
        'Annual Popcorn Consumption':'APC'
    }, index = {
        'United states':'USA',
        'United Kingdom':'Uk',
        'Argentina': 'AR'
    })
# Out:
#               Population         GDP  Surface Area  Human Development Index  \
# Canada            35.467   1785387.0       9984670                    0.913
# France            63.951   2833687.0        640679                    0.888
# Germany           80.940         NaN        357114                    0.916
# Italy             60.665   2167744.0        301336                    0.873
# Japan            127.061   4602367.0        377930                    0.891
# Uk                64.511   2950039.0        242495                    0.907
# United State     318.523  17348075.0       9525067                    0.915
#
#              Continent  Language
# Canada         America   English
# France          Europe   Italian
# Germany         Europe   English
# Italy           Europe   English
# Japan             Asia  Japanese
# Uk              Europe   English
# United State   America   English

# %%
df.rename(index=str.upper)
# Out:
#                 Population         GDP  Surface Area    HDI Continent  \
# CANADA              35.467   1785387.0       9984670  0.913   America
# FRANCE              63.951   2833687.0        640679  0.888    Europe
# GERMANY             80.940         NaN        357114  0.916    Europe
# ITALY               60.665   2167744.0        301336  0.873    Europe
# JAPAN              127.061   4602367.0        377930  0.891      Asia
# UNITED KINGDOM      64.511   2950039.0        242495  0.907    Europe
# UNITED STATE       318.523  17348075.0       9525067  0.915   America
#
#                 Language
# CANADA           English
# FRANCE           Italian
# GERMANY          English
# ITALY            English
# JAPAN           Japanese
# UNITED KINGDOM   English
# UNITED STATE     English

# %%
df.rename(index=lambda x:x.lower())
# Out:
#                 Population         GDP  Surface Area    HDI Continent  \
# canada              35.467   1785387.0       9984670  0.913   America
# france              63.951   2833687.0        640679  0.888    Europe
# germany             80.940         NaN        357114  0.916    Europe
# italy               60.665   2167744.0        301336  0.873    Europe
# japan              127.061   4602367.0        377930  0.891      Asia
# united kingdom      64.511   2950039.0        242495  0.907    Europe
# united state       318.523  17348075.0       9525067  0.915   America
#
#                 Language
# canada           English
# france           Italian
# germany          English
# italy            English
# japan           Japanese
# united kingdom   English
# united state     English

# %%
#dropping columns
df.drop(columns='Language',inplace=True)

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent
# Canada              35.467   1785387.0       9984670  0.913   America
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America

# %%
#adding values
df.append(pd.Series({
    'Population':3,'Surface Area':2000,
    'GDP':5
}, name='China')) #Append returns a new dataframe
# Out:
# <ipython-input-127-e6b2c0819ec1>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(pd.Series({
#                 Population         GDP  Surface Area    HDI Continent
# Canada              35.467   1785387.0       9984670  0.913   America
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America
# China                3.000         5.0          2000    NaN       NaN

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent
# Canada              35.467   1785387.0       9984670  0.913   America
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America

# %%
#creating columns from other columns- Altering a dataframe often involves combining differnet columns into another.For example, in our countries analysis, we could try to calculate the 'GDP per capita, which is just, GDP/Popuplation
df[['Population','GDP']]
# Out:
#                 Population         GDP
# Canada              35.467   1785387.0
# France              63.951   2833687.0
# Germany             80.940         NaN
# Italy               60.665   2167744.0
# Japan              127.061   4602367.0
# United Kingdom      64.511   2950039.0
# United State       318.523  17348075.0

# %%
#the regular pandas way of expressing that, is just dividing each series:
df['GDP']/df['Population']
# Out:
# Canada            50339.385908
# France            44310.284437
# Germany                    NaN
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United State      54464.120330
# dtype: float64

# %%
#the result of that operation is just another series that you can add to the original dataframe
df['GDF per Capita']=df['GDP']/df['Population']

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387.0       9984670  0.913   America
# France              63.951   2833687.0        640679  0.888    Europe
# Germany             80.940         NaN        357114  0.916    Europe
# Italy               60.665   2167744.0        301336  0.873    Europe
# Japan              127.061   4602367.0        377930  0.891      Asia
# United Kingdom      64.511   2950039.0        242495  0.907    Europe
# United State       318.523  17348075.0       9525067  0.915   America
#
#                 GDF per Capita
# Canada            50339.385908
# France            44310.284437
# Germany                    NaN
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United State      54464.120330

# %%
#Statistical info-
df.head()
# Out:
#          Population        GDP  Surface Area    HDI Continent  GDF per Capita
# Canada       35.467  1785387.0       9984670  0.913   America    50339.385908
# France       63.951  2833687.0        640679  0.888    Europe    44310.284437
# Germany      80.940        NaN        357114  0.916    Europe             NaN
# Italy        60.665  2167744.0        301336  0.873    Europe    35733.025633
# Japan       127.061  4602367.0        377930  0.891      Asia    36221.712406

# %%
df.describe(include='all')
# Out:
#         Population           GDP  Surface Area       HDI Continent  \
# count     7.000000  6.000000e+00  7.000000e+00  7.000000         7
# unique         NaN           NaN           NaN       NaN         3
# top            NaN           NaN           NaN       NaN    Europe
# freq           NaN           NaN           NaN       NaN         4
# mean    107.302571  5.281216e+06  3.061327e+06  0.900429       NaN
# std      97.249970  5.990146e+06  4.576187e+06  0.016592       NaN
# min      35.467000  1.785387e+06  2.424950e+05  0.873000       NaN
# 25%      62.308000  2.334230e+06  3.292250e+05  0.889500       NaN
# 50%      64.511000  2.891863e+06  3.779300e+05  0.907000       NaN
# 75%     104.000500  4.189285e+06  5.082873e+06  0.914000       NaN
# max     318.523000  1.734808e+07  9.984670e+06  0.916000       NaN
#
#         GDF per Capita
# count         6.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean      44466.294781
# ...

# %%
population=df['Population']

# %%
population.min(),population.max()
# Out:
# (35.467, 318.523)

# %%
population.sum()
# Out:
# 751.118

# %%
population.sum()/len(population)
# Out:
# 107.30257142857144

# %%
population.mean()
# Out:
# 107.30257142857144

# %%
population.std()
# Out:
# 97.24996987121581

# %%
population.median()
# Out:
# 64.511

# %%
population.describe()
# Out:
# count      7.000000
# mean     107.302571
# std       97.249970
# min       35.467000
# 25%       62.308000
# 50%       64.511000
# 75%      104.000500
# max      318.523000
# Name: Population, dtype: float64

# %%
population.quantile(.25)
# Out:
# 62.308

# %%
population.quantile([.2,.4,.6,.8,1])
# Out:
# 0.2     61.3222
# 0.4     64.1750
# 0.6     74.3684
# 0.8    117.8368
# 1.0    318.5230
# Name: Population, dtype: float64

# %% [markdown]
# WORKING WITH MISSING DATA

# %%
#renaming columns
df= df.rename(
    columns={
        'HDI': 'Human Development Index',
        'GDP':'Gross domestic product'},
    index={
        'United states': 'USA',
        'United kingdom':'UK',
        'France':'FR'})

# %%
df.rename(columns=lambda x:x.lower())

# %%
df.rename(index=str.upper)

# %%
df.rename(index=lambda x:x.lower())

# %%
#Dropping columns

# %%
df.drop(columns='Language',inplace=True)

# %%
df

# %% [markdown]
# Handling Missing Data
# There are several useful methods for detecting,removing, and replacing null values in pandas data structures. They are:
# isnull():Generate a boolean mask indicating missing values
# notnull():opposite of isnull()
# dropna(): return a filtered version of the data
# fillna():return a copy of the data with missing values filled or imputed

# %%
import pandas as pd

# %%
import numpy as np

# %%
#NaN:Missing numerical data- The other missing data representation,NaN(acronym for Not a Number)is different;it is a special floating-point value recognized by all systems that use the standard IEEE floating point representation

# %% [markdown]
# NaN and None
# NaN and None both have their place, and pandas is built to handle the two of them rearly interchangeably converting between then where appropriate.
# Operating on Null Values
# There are several useful methods for detecting, removing and replacing null values in pandas data structures. Ther are:isnull(),notnull(),dropna(),fillna().
# Detecting null values
# Pandas data structures have two useful methods for detecting null data. isnull() and notnull(). Either one will return a Boolean mask over the data. For example:

# %%
data= pd.series([1,np.nan,'hello',None])

# %%
data.isnull()

# %%
data[data.notnull()] #the isnull() and notnull() produce similar Boolean results for Dataframes

# %% [markdown]
# Dropping null values. In addition to the masking used before, there are the convenience methods,dropna() which removes NA values and fillna(). which fills in NA values. For a series, the result is straightforward

# %%
data.dropna()

# %%
#for a dataframe, there are more options. consider the following dataframe:
df=pd.Dataframe([[1, np.man,2],
                 [2,3,5],
                 [np.nan,4,6]])
df

# %%
df.rename(columns=({0:'A',1:'B',2:'C'}))

# %%
df

# %% [markdown]
# We cannot drop single values from a Dataframe: we can only drop full rows or full columns.Depending on the application,you might want one or the other. so dropna() gives a number of options for a dataframe. By default, dropna() will drop all rows in which any null value is present.
#
# df.dropna()

# %% [markdown]
# Alternatively, you can drop NA values along a different axis: axis=1 drops all columns containing a null value:

# %%
df.dropna(axis='columns')

# %% [markdown]
# but this drops some good data as well; you might rather be interested in dropping rows or columns with all NA values, or a majority of NA values. This can be specified through the how or thresh parameters which allow fine control of the number of nulls to allow through. The default is how='any', such that any row or column(depending on the axis keyword) containing a null value will be dropped. You can also specify how='all', which will only drop rows/columns that are all null values:

# %%
df[D]=np.nan
df

# %%
df.dropna(axis='columns',how='all')

# %% [markdown]
# for finer-grained control, the thresh parameter lets you specify a minimum number of non-null values for the row/column to be kept:

# %%
df.dropna(axis='columns',thresh=1)

# %%
df['E']=2

# %%
df.iloc[:2,-1]=np.nan

# %%
df

# %% [markdown]
# Filling null values
# Sometimes rather than dropping NA values,you'd rather replace them with a valid value.This value might be a single number like zero, or it might be some sort of imputation or interpolation from the good values. You could do this in-place using the isnull() method as a mask, but because it is such a common operation Pandas provides the fillna() method, which return a copy of the array with the null values replaced.
# Consider the following series:

# %%
data=pd.series([1,np.nan,2,None,3],index=list('abcde'))
data

# %%
#We can fill NA entries with a single value,such as zero:
data.fillna(0)

# %%
#we can specify a forward-fill to propagate the previous value forward:
#forward-fill
data.fillna(method='ffill')

# %%
#or we can specify a back-fill to propagate the next values backward:
#back-fill
data.fillna(method='bfill')

# %%
#for dataframe the options are simliar, but we can also specify an axis along which the fills take place:
df

# %%
df.fillna(method='ffill',axis=1)

# %% [markdown]
# Merge & Joining,Group and Concatenation
# The pd.merge() function implements a number of types of joins: the one-to-one, many-to-one, and many-to-many joins.
# Grouping is an essential piece of analysis of large data is effcient summarization.
# pd.concat() can be used for a simple concatenation of Series or DataFrame objects

# %%
#Combining Datasets:Merge and Join
import pandas as pd
import numpy as np

class display(object):
  """Display HTML representation of multiple objects"""
  template = """<div style="float:left;padding:10px;">
  <p style ='font-family:"Courier New",Courier,monospace'>{0}</p>{1}
  </div>"""
  def __int__(self,*args):
    self.args=args

  def _repr_html_(self):
    return'\n'.join(self.template.format(a,eval(a)._repr_html())
                    for a in self.args)
  def__repr__(self):
    return '\n\n'.join(a+'\n'+repr(eval(a))
                        for a in self.args)
# Out:
#   File "<ipython-input-9-51e04ff58f34>", line 16
#     def__repr__(self):
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# Categories of joins
# The pd.merge() function implements a number of types of joins; the one-to-one, many-to-one, and many-to-many joins.
# One-to-one joins

# %%
import pandas as pd

# %%
import numpy as np

# %%
df1=pd.DataFrame({'employee':['Bob','Jake','Lisa','Sue','Bob'],
                  'group':['Accounting','Engineering','Engineering','HR','Sales']})
df2=pd.DataFrame({'employee':['Lisa','Bob','Jake','Sue'],
                  'hire_date':[2004,2008,2012,2014]})
display('df1','df2')
# Out:
# 'df1'
# 'df2'

# %%
df3=pd.merge(df1,df2) #To combine this information into a single DataFrame, we can use the pd.merge() function
df3
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1      Bob        Sales       2008
# 2     Jake  Engineering       2012
# 3     Lisa  Engineering       2004
# 4      Sue           HR       2014

# %%
df1
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
# 4      Bob        Sales

# %%
df2
# Out:
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014

# %%
#The pd.merge() function recognizes that each DataFrame has an 'employee' column, and automatically joins using this column as a key

# %%
#Many-to-one joins; are joins in which one of the two key columns contains duplicate entries
df4=pd.DataFrame({'group':['Accounting','Engineering','HR'],
                  'supervisor':['Carly','Guido','Steve']})
display('df3','df4','pd.merge(df3,df4)')
# Out:
# 'df3'
# 'df4'
# 'pd.merge(df3,df4)'

# %%
pd.merge(df3,df4)
# Out:
#   employee        group  hire_date supervisor
# 0      Bob   Accounting       2008      Carly
# 1     Jake  Engineering       2012      Guido
# 2     Lisa  Engineering       2004      Guido
# 3      Sue           HR       2014      Steve

# %% [markdown]
# The resulting DataFrame has an additional column with the 'supervisor' information, where the information is repeated in one or more locations as required by the inputs

# %% [markdown]
# Many-to-Many joins- are a bit confusing conceptually, but are nevertheless well defined. if the key column in both the left and right array contains duplicates,then the result is a many-to-many merge

# %%
df5=pd.DataFrame({'group': ['Accounting','Accounting','Engineering','Engineering','HR','HR'],
                  'skills':['math','spreadsheets','coding','linux','spreadsheets','organization']})
df6=pd.merge(df1,df5)
display('df1','df5','df6')
# Out:
# 'df1'
# 'df5'
# 'df6'

# %%
df6
# Out:
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %%
#Specify the Merge Key-The on Keyword.Most simply,you can explicitly specify the name of the key column using the on keyword,which takes a column name or a list of column names:
df7=pd.merge(df1,df2,on='employee')
display('df1','df2','df7')
# Out:
# 'df1'
# 'df2'
# 'df7'

# %%
df7
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1      Bob        Sales       2008
# 2     Jake  Engineering       2012
# 3     Lisa  Engineering       2004
# 4      Sue           HR       2014

# %% [markdown]
# This option works only if both the left and right DataFrames have the specified column name

# %% [markdown]
# The Left_on and right_on keywords- At times you may wish to merge two datasets with different column names;for example,we may have a dataset in which the employee name is labeled as 'name' rather than 'employee'. In this case, we can use the left_on and right_on keywords to specify the two column names:

# %%
df3= pd.DataFrame({'name':['Bob','Jake','Lisa','Sue'],
                   'salary': [70000,80000,120000,90000]})
df8 = pd.merge(df1,df3,left_on="employee",right_on="name")
display('df1','df3','df8')
# Out:
# 'df1'
# 'df3'
# 'df8'

# %%
df8
# Out:
#   employee        group  name  salary
# 0      Bob   Accounting   Bob   70000
# 1      Bob        Sales   Bob   70000
# 2     Jake  Engineering  Jake   80000
# 3     Lisa  Engineering  Lisa  120000
# 4      Sue           HR   Sue   90000

# %% [markdown]
# The result has a redundant column that we can drop if desired-for example,by using the drop() method of DataFrames

# %%
pd.merge(df1,df3,left_on="employee",right_on="name").drop('name',axis=1)
# Out:
#   employee        group  salary
# 0      Bob   Accounting   70000
# 1      Bob        Sales   70000
# 2     Jake  Engineering   80000
# 3     Lisa  Engineering  120000
# 4      Sue           HR   90000

# %%
#when you merge it increases your column, when you concat or append it increases the number of rows

# %% [markdown]
# Combining Datasets:Concat and Append

# %%
import pandas as pd

class display (object):
  """Display HTML representation of multiple objects"""
  template = """<div style="float:left;padding:10px;">
  <p style='font-family:"Courier New",Courier,monospace'>{0}</p>{1}
  </div>"""
  def __init__(self,*args):
    self.args=args
  def _repr_html_(self):
    return '\n'.join(self.template.format(a,eval(a)._repr_html_())
                    for a in self.args)
  def __repr__(self):
    return '\n\n'.join(a+'\n'+repr(eval(a))
                      for a in self.args)

# %% [markdown]
# For convenience, we'll define this function which creates a DataFrame of a particular form that will be useful below:

# %%
#Simple Concatenation with pd.concat

# syntax:
#      pd.concat(objs,axis=0,join='outer',join_axes=None,ignore_index=False,
          #keys=None, levels=None, names=None, verify_integrity=False,
          #copy=True)
  #pd.concat() can be used for a simple concatenation of Series or DataFrame Objects
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-06fb17ed8360> in <cell line: 3>()
#       1 #Simple Concatenation with pd.concat
#       2
# ----> 3 pd.concat(objs,axis=0,join='outer',join_axes=None,ignore_index=False,
#       4           keys=None, levels=None, names=None, verify_integrity=False,
#       5           copy=True)
#
# NameError: name 'objs' is not defined

# %%
ser1=pd.Series(['A','B','C'],index=[1,2,3])
ser2=pd.Series(['D','E','F'], index=[4,5,6])
pd.concat([ser1,ser2])
# Out:
# 1    A
# 2    B
# 3    C
# 4    D
# 5    E
# 6    F
# dtype: object

# %%
#it also works to concatenate higher-dimensionap objects,such as DataFrames:
df1=pd.DataFrame({'AB':[1,2]})
df2=pd.DataFrame({'AB':[3,4]})
display('df1','df2','pd.concat([df1,df2])')
# Out:
# df1
#    AB
# 0   1
# 1   2
#
# df2
#    AB
# 0   3
# 1   4
#
# pd.concat([df1,df2])
#    AB
# 0   1
# 1   2
# 0   3
# 1   4

# %%
#By defualt, the concatenation takes place row-wise within the DataFrame (i.e., axis=0).Like np.concatenate, pd.concat allows specification of an axis along which concatenation will take place. Consider the following example:
df3=pd.DataFrame({'AB':[0,1]})
df4=pd.DataFrame({'CD':[1,0]})
display('df3','df4',"pd.concat([df3,df4],axis=1)")
# Out:
# df3
#    AB
# 0   0
# 1   1
#
# df4
#    CD
# 0   1
# 1   0
#
# pd.concat([df3,df4],axis=1)
#    AB  CD
# 0   0   1
# 1   1   0

# %%
#we could have equivalently specified axis=1; here we've used the more intuitive axis='col
df3=pd.DataFrame({'AB':[0,1]})
df4=pd.DataFrame({'CD':[1,0]})
display('df3','df4',"pd.concat([df3,df4],axis=0)")
# Out:
# df3
#    AB
# 0   0
# 1   1
#
# df4
#    CD
# 0   1
# 1   0
#
# pd.concat([df3,df4],axis=0)
#     AB   CD
# 0  0.0  NaN
# 1  1.0  NaN
# 0  NaN  1.0
# 1  NaN  0.0

# %%
#we could have equivalently specified axis=0; here we have used the more intuitive axis='row

# %% [markdown]
# The append() method
# Because direct array concatenation is so common, Series and DataFrame objects have an append method that can accomplish the same thing in fewer keystrokes. For example, rather than calling pd.concat([df1,df2]), you can simply call df1.append(df2)

# %%
display('df1','df2','df1.append(df2)')
# Out:
# <string>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <string>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# df1
#    AB
# 0   1
# 1   2
#
# df2
#    AB
# 0   3
# 1   4
#
# df1.append(df2)
#    AB
# 0   1
# 1   2
# 0   3
# 1   4

# %% [markdown]
# GroupBy
# An essential piece of analysis of large data is efficient summarization: computing aggregations like sum(),mean(),median(),min(),and max(), in which a single number gives insight into the nature of a potentially large dataset.
# The following table summarizes some other built-in Pandas aggregations that can be used with the groupby function
# Aggregation       Description
# count()           TOTAL Number of items
# first().last()    first and last item
# mean().median()   mean and median
# min().max()       minimum and maximum
# std().var()       standard deviation and variance
# mad()             mean absolute deviation
# prod()            product of all items
# sum()             sun of all items
#
# These are all methods of DataFrame and Series objects.

# %%
df= pd.DataFrame({'key':['A','B','C','A','B','C'],
                 'data':range(0,12,2)},columns=['key','data'])
df
# Out:
#   key  data
# 0   A     0
# 1   B     2
# 2   C     4
# 3   A     6
# 4   B     8
# 5   C    10

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.groupby('key')['data'].min()
# Out:
# key
# A    0
# B    2
# C    4
# Name: data, dtype: int64

# %% [markdown]
# Notice that what is returned is not a set of Dataframes but a DataFrameGroupBy object. This object is where the magic is: you can think of it as a special view of the DataFrame, which is poised to dig into the groups but does no actual computation until the aggregation is applied. This 'lazy exvaluation' approach means that common aggregates can be implemented very efficiently in a way that is almost transparent to the user.
# To produce a result, we can apply an aggregate to this DataFrameGroupBy object, which will perform the appropriate apply/combine steps to produce the desired result:

# %%
df.groupby('key').sum()
# Out:
#      data
# key
# A       6
# B      10
# C      14

# %% [markdown]
# The sum() method is just one possibility here; you can apply virtually any common Pandas or Numpy aggregation function, as well as virtually any valid DataFrame operation, as we will see in the following discussion

# %%
import pandas as pd

# %%
df= pd.read_csv('sales_data_csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-bfb70dac2c5b> in <cell line: 1>()
# ----> 1 df= pd.read_csv('sales_data_csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head()

# %%
df.info()

# %%
df.groupby('Year')['Year'].count()

# %%
df.groupby('Country')['State'].describe()

# %%
rev=df.groupby(['Country','State'])['Revenue'].sum()

# %%
rev

# %%
rev['United states']

# %% [markdown]
# PANDAS OPERATIONS

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('file_example.xlsx')

# %%
df.tail()

# %%
df.shape

# %%
df.info()

# %%
print('The number of rows is {}, and column is {}.The size of the file is {}')

# %% [markdown]
# Row and Column selection

# %%
df[['First Name','Last Name']]

# %%
df.iloc[2:7,1:5]

# %%
df.iloc[2:5]

# %% [markdown]
# Null Values

# %%
first_name = input('Enter your first name:')
last_name = input('Enter your last name: ')
gender = input('Enter your gender:')
country = input('Enter your country: ')
age = int(input('Enter your age:'))
date = input('Enter your dob:')

# %%
from sys import last_traceback
new_val = {
    'First Name': first_name,
    'Last Name': last_name,
    'Gender': gender,
    'Country': country,
    'Age': age,
    'Date':date,
    'Id': np.nan
}

# %%
df = df.append(new_val,ignore_index=True)

# %%
df

# %%
df.isna()

# %%
df.isnull()

# %%
df.dropna(axis=1)

# %%
#String Operation

df['First Name'].str.lower()

# %%
df['Last Name'].str.upper()

# %%
df['Full Name']=(df['First Name'].str.lower()+ ''+df['Last Name'].str.upper())

# %%
df
